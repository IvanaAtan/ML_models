# %% [markdown]
# ### Results (DT,RF,KNN) - 1

# %%
import pandas as pd
df = pd.read_csv('log_table1.csv')
df
# Out:
#    Model Hyperparameter Algorithm  Metric  Metric score  Elapsed time
# 0     RF        RandomizedSearchCV    MAE      0.050779    343.810534
# 1     RF        RandomizedSearchCV    MSE      0.010004    343.810534
# 2     RF        RandomizedSearchCV     R2      0.869194    343.810534
# 3     DT        RandomizedSearchCV    MAE      0.075098      1.342806
# 4     DT        RandomizedSearchCV    MSE      0.021261      1.342806
# 5     DT        RandomizedSearchCV     R2      0.721470      1.342806
# 6    KNN        RandomizedSearchCV    MAE      0.054596     16.017105
# 7    KNN        RandomizedSearchCV    MSE      0.013043     16.017105
# 8    KNN        RandomizedSearchCV     R2      0.829513     16.017105
# 9     RF              GridSearchCV    MAE      0.054596   7045.012882
# 10    RF              GridSearchCV    MSE      0.013043   7045.012882
# 11    RF              GridSearchCV     R2      0.829513   7045.012882
# ...
